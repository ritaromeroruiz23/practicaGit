# %% [markdown]
# <a href="https://colab.research.google.com/github/ritaromeroruiz23/practicaGit/blob/main/Proyecto2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/kiva_loans.csv')
pd.read_csv('/content/kiva_loans.csv')
# Out:
#              id  funded_amount  loan_amount             activity  \
# 0        653051          300.0        300.0  Fruits & Vegetables
# 1        653053          575.0        575.0             Rickshaw
# 2        653068          150.0        150.0       Transportation
# 3        653063          200.0        200.0           Embroidery
# 4        653084          400.0        400.0           Milk Sales
# ...         ...            ...          ...                  ...
# 643377  1305379          525.0        525.0            Livestock
# 643378  1305330          225.0        225.0        General Store
# 643379  1305133          250.0        250.0                 Pigs
# 643380  1305535          525.0        525.0        General Store
# 643381  1304843          125.0        125.0              Fishing
#
#                 sector                                                use  \
# 0                 Food            To buy seasonal, fresh fruits to sell.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581654 entries, 0 to 581653
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  581654 non-null  int64
#  1   funded_amount       581654 non-null  float64
#  2   loan_amount         581654 non-null  float64
#  3   activity            581654 non-null  object
#  4   sector              581654 non-null  object
#  5   use                 577501 non-null  object
#  6   country_code        581645 non-null  object
#  7   country             581653 non-null  object
#  8   region              529374 non-null  object
#  9   currency            581653 non-null  object
#  10  partner_id          569072 non-null  float64
#  11  posted_time         581653 non-null  object
#  12  disbursed_time      579704 non-null  object
#  13  funded_time         542436 non-null  object
#  14  term_in_months      581653 non-null  float64
# ...

# %%
df.shape
# Out:
# (581654, 20)

# %%
df.count()
# Out:
# id                    581654
# funded_amount         581654
# loan_amount           581654
# activity              581654
# sector                581654
# use                   577501
# country_code          581645
# country               581653
# region                529374
# currency              581653
# partner_id            569072
# posted_time           581653
# disbursed_time        579704
# funded_time           542436
# term_in_months        581653
# lender_count          581653
# tags                  422157
# borrower_genders      577512
# repayment_interval    581653
# date                  581653
# dtype: int64
